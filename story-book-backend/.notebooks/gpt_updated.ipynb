# %%
story_book = {
  "story_title": "Jungle Adventure: Tara and Leo's Wild Day",
  "story_description": "Join Tara and Leo as they embark on a magical adventure through a jungle, discovering new friends and overcoming challenges.",
  "story_characters": [
    {
      "character_name": "Tara",
      "character_description": "Tara is a curious and adventurous 7-year-old girl with bright blue eyes and wavy brown hair tied up in a ponytail. She wears a yellow t-shirt and green shorts, and her shoes are sturdy hiking boots. Her cheerful and brave personality makes her a natural leader.",
      "character_image_path": "images/tara.png"
    },
    {
      "character_name": "Leo",
      "character_description": "Leo is a playful 6-year-old boy with curly black hair and warm brown eyes. He wears a red cap, a blue t-shirt, and denim shorts. His sneakers are always ready for a run. Leo is full of energy and loves to explore new places.",
      "character_image_path": "images/leo.png"
    }
  ],
  "story_book": [
    {
      "page": 1,
      "story_text": "One sunny morning, Tara and Leo set off on an exciting adventure. 'Let's explore the jungle,' said Tara, her eyes sparkling with excitement.",
      "illustration_description": "Tara and Leo are standing at the edge of a lush jungle. Tara is pointing towards the trees, her face lit up with enthusiasm. Leo is beside her, looking eager and ready to go. The jungle is vibrant with tall green trees and colorful flowers in the foreground.",
      "characters": [
        {
          "character_name": "Tara",
          "character_description": "Tara is a curious and adventurous 7-year-old girl with bright blue eyes and wavy brown hair tied up in a ponytail. She wears a yellow t-shirt and green shorts, and her shoes are sturdy hiking boots. Her cheerful and brave personality makes her a natural leader.",
          "character_image_path": "images/tara.png"
        },
        {
          "character_name": "Leo",
          "character_description": "Leo is a playful 6-year-old boy with curly black hair and warm brown eyes. He wears a red cap, a blue t-shirt, and denim shorts. His sneakers are always ready for a run. Leo is full of energy and loves to explore new places.",
          "character_image_path": "images/leo.png"
        }
      ]
    },
    {
      "page": 2,
      "story_text": "As Tara and Leo wandered deeper into the jungle, they heard the chatter of monkeys and the rustle of leaves. 'Wow, this place is amazing!' exclaimed Leo.",
      "illustration_description": "Tara and Leo are walking along a jungle path, surrounded by tall trees and vines. Monkeys can be seen swinging in the trees above, and a few colorful birds are perched on branches. The sunlight filters through the leaves, creating a magical atmosphere.",
      "characters": [
        {
          "character_name": "Tara",
          "character_description": "Tara is a curious and adventurous 7-year-old girl with bright blue eyes and wavy brown hair tied up in a ponytail. She wears a yellow t-shirt and green shorts, and her shoes are sturdy hiking boots. Her cheerful and brave personality makes her a natural leader.",
          "character_image_path": "images/tara.png"
        },
        {
          "character_name": "Leo",
          "character_description": "Leo is a playful 6-year-old boy with curly black hair and warm brown eyes. He wears a red cap, a blue t-shirt, and denim shorts. His sneakers are always ready for a run. Leo is full of energy and loves to explore new places.",
          "character_image_path": "images/leo.png"
        }
      ]
    },
    {
      "page": 3,
      "story_text": "Suddenly, Tara and Leo came across a sparkling stream. 'Let's splash a little!' Tara giggled, dipping her toes in the cool water.",
      "illustration_description": "Tara and Leo are by a clear, sparkling stream. Tara is playfully splashing water with her feet, and Leo is laughing as he watches her. The stream is surrounded by small rocks and lush ferns, with a few colorful fish visible in the water.",
      "characters": [
        {
          "character_name": "Tara",
          "character_description": "Tara is a curious and adventurous 7-year-old girl with bright blue eyes and wavy brown hair tied up in a ponytail. She wears a yellow t-shirt and green shorts, and her shoes are sturdy hiking boots. Her cheerful and brave personality makes her a natural leader.",
          "character_image_path": "images/tara.png"
        },
        {
          "character_name": "Leo",
          "character_description": "Leo is a playful 6-year-old boy with curly black hair and warm brown eyes. He wears a red cap, a blue t-shirt, and denim shorts. His sneakers are always ready for a run. Leo is full of energy and loves to explore new places.",
          "character_image_path": "images/leo.png"
        }
      ]
    },
    {
      "page": 4,
      "story_text": "After the splash, Tara and Leo decided to climb a giant tree. 'I can see so far!' shouted Leo from the top branch, waving at Tara.",
      "illustration_description": "Leo is perched on a high branch of a giant tree, looking out over the jungle with a big smile. Tara is climbing up behind him, her face filled with determination and fun. The tree is enormous, with thick branches and a view of the lush jungle canopy below.",
      "characters": [
        {
          "character_name": "Tara",
          "character_description": "Tara is a curious and adventurous 7-year-old girl with bright blue eyes and wavy brown hair tied up in a ponytail. She wears a yellow t-shirt and green shorts, and her shoes are sturdy hiking boots. Her cheerful and brave personality makes her a natural leader.",
          "character_image_path": "images/tara.png"
        },
        {
          "character_name": "Leo",
          "character_description": "Leo is a playful 6-year-old boy with curly black hair and warm brown eyes. He wears a red cap, a blue t-shirt, and denim shorts. His sneakers are always ready for a run. Leo is full of energy and loves to explore new places.",
          "character_image_path": "images/leo.png"
        }
      ]
    },
    {
      "page": 5,
      "story_text": "Just then, Tara spotted a colorful parrot. 'Hello, Polly!' she called. The parrot flapped its wings and squawked back, 'Hello, Tara!'",
      "illustration_description": "A colorful parrot is perched on a branch near Tara and Leo. Tara is reaching out with a friendly wave, and the parrot is mimicking her greeting with its wings spread wide. The scene is full of vibrant colors, with leaves and flowers adding to the lively atmosphere.",
      "characters": [
        {
          "character_name": "Tara",
          "character_description": "Tara is a curious and adventurous 7-year-old girl with bright blue eyes and wavy brown hair tied up in a ponytail. She wears a yellow t-shirt and green shorts, and her shoes are sturdy hiking boots. Her cheerful and brave personality makes her a natural leader.",
          "character_image_path": "images/tara.png"
        },
        {
          "character_name": "Leo",
          "character_description": "Leo is a playful 6-year-old boy with curly black hair and warm brown eyes. He wears a red cap, a blue t-shirt, and denim shorts. His sneakers are always ready for a run. Leo is full of energy and loves to explore new places.",
          "character_image_path": "images/leo.png"
        }
      ]
    },
    {
      "page": 6,
      "story_text": "As the sun began to set, Tara and Leo knew it was time to head back. 'What a day!' said Tara. 'Let's come back tomorrow!'",
      "illustration_description": "Tara and Leo are walking back through the jungle as the sky turns a warm orange and pink with the setting sun. They look happy and a bit tired, holding hands as they make their way home. The jungle is calm and peaceful, with the last rays of sun peeking through the trees.",
      "characters": [
        {
          "character_name": "Tara",
          "character_description": "Tara is a curious and adventurous 7-year-old girl with bright blue eyes and wavy brown hair tied up in a ponytail. She wears a yellow t-shirt and green shorts, and her shoes are sturdy hiking boots. Her cheerful and brave personality makes her a natural leader.",
          "character_image_path": "images/tara.png"
        },
        {
          "character_name": "Leo",
          "character_description": "Leo is a playful 6-year-old boy with curly black hair and warm brown eyes. He wears a red cap, a blue t-shirt, and denim shorts. His sneakers are always ready for a run. Leo is full of energy and loves to explore new places.",
          "character_image_path": "images/leo.png"
        }
      ]
    }
  ]
}

# %%
story_book = {
  "story_title": "Tara and Leo's Jungle Adventure",
  "story_description": "Join Tara and Leo as they explore the magical jungle and find their way back home. Perfect for young adventurers aged 2-6.",
  "story_characters": [
    {
      "character_name": "Tara",
      "character_description": "Tara is a curious 5-year-old girl with bright, sparkling eyes and curly brown hair. She's brave and loves exploring new places. Tara is always ready for an adventure and wears a playful, colorful outfit.",
      "character_image_path": "images/tara.png"
    },
    {
      "character_name": "Leo",
      "character_description": "Leo is Tara's 4-year-old brother. He has a big smile and blond hair that sticks up in all directions. Leo is full of energy and laughter, and he loves following his sister on her adventures. He wears a fun, striped shirt and shorts.",
      "character_image_path": "images/leo.png"
    }
  ],
  "story_book": [
    {
      "page": 1,
      "story_text": "One sunny morning, Tara and her brother Leo set off on an adventure. They were excited to explore the big, green jungle!",
      "illustration_description": "Tara and Leo stand at the edge of a vibrant jungle. Tara is pointing forward with excitement, while Leo bounces on his toes, smiling widely. The jungle is lush with trees and colorful flowers.",
      "characters": [
        {
          "character_name": "Tara",
          "character_description": "Tara is a curious 5-year-old girl with bright, sparkling eyes and curly brown hair. She's brave and loves exploring new places. Tara is always ready for an adventure and wears a playful, colorful outfit.",
          "character_image_path": "images/tara.png"
        },
        {
          "character_name": "Leo",
          "character_description": "Leo is Tara's 4-year-old brother. He has a big smile and blond hair that sticks up in all directions. Leo is full of energy and laughter, and he loves following his sister on her adventures. He wears a fun, striped shirt and shorts.",
          "character_image_path": "images/leo.png"
        }
      ]
    },
    {
      "page": 2,
      "story_text": "Tara and Leo walked deeper into the jungle. They saw tall trees, chirping birds, and a little monkey swinging by!",
      "illustration_description": "Tara and Leo walking under the canopy of tall trees. Birds are flying above, and a cute monkey is swinging from a vine, waving at them. The jungle is alive with sounds and colors.",
      "characters": [
        {
          "character_name": "Tara",
          "character_description": "Tara is a curious 5-year-old girl with bright, sparkling eyes and curly brown hair. She's brave and loves exploring new places. Tara is always ready for an adventure and wears a playful, colorful outfit.",
          "character_image_path": "images/tara.png"
        },
        {
          "character_name": "Leo",
          "character_description": "Leo is Tara's 4-year-old brother. He has a big smile and blond hair that sticks up in all directions. Leo is full of energy and laughter, and he loves following his sister on her adventures. He wears a fun, striped shirt and shorts.",
          "character_image_path": "images/leo.png"
        }
      ]
    },
    {
      "page": 3,
      "story_text": "Suddenly, Tara and Leo found a sparkling river. 'Let's follow it!' said Tara. Leo nodded, 'Yes, let's go!'",
      "illustration_description": "Tara and Leo standing by a sparkling river. Tara is pointing along the river, and Leo is looking with excitement. The sunlight is dancing on the water, and there are colorful fish swimming.",
      "characters": [
        {
          "character_name": "Tara",
          "character_description": "Tara is a curious 5-year-old girl with bright, sparkling eyes and curly brown hair. She's brave and loves exploring new places. Tara is always ready for an adventure and wears a playful, colorful outfit.",
          "character_image_path": "images/tara.png"
        },
        {
          "character_name": "Leo",
          "character_description": "Leo is Tara's 4-year-old brother. He has a big smile and blond hair that sticks up in all directions. Leo is full of energy and laughter, and he loves following his sister on her adventures. He wears a fun, striped shirt and shorts.",
          "character_image_path": "images/leo.png"
        }
      ]
    },
    {
      "page": 4,
      "story_text": "As they walked, Tara and Leo heard a rustle. Out popped a friendly parrot, 'Hello!' it squawked.",
      "illustration_description": "Tara and Leo looking surprised as a colorful parrot appears from the bushes. The parrot is perched on a low branch, speaking to them. The jungle is lush with greenery and small flowers.",
      "characters": [
        {
          "character_name": "Tara",
          "character_description": "Tara is a curious 5-year-old girl with bright, sparkling eyes and curly brown hair. She's brave and loves exploring new places. Tara is always ready for an adventure and wears a playful, colorful outfit.",
          "character_image_path": "images/tara.png"
        },
        {
          "character_name": "Leo",
          "character_description": "Leo is Tara's 4-year-old brother. He has a big smile and blond hair that sticks up in all directions. Leo is full of energy and laughter, and he loves following his sister on her adventures. He wears a fun, striped shirt and shorts.",
          "character_image_path": "images/leo.png"
        }
      ]
    },
    {
      "page": 5,
      "story_text": "'Where are you going?' asked the parrot. 'We're exploring!' said Tara. 'Can you help us?'",
      "illustration_description": "Tara and Leo talking to the parrot. Tara is gesturing with her hands as she explains their adventure. The parrot is listening attentively, with its head tilted to one side.",
      "characters": [
        {
          "character_name": "Tara",
          "character_description": "Tara is a curious 5-year-old girl with bright, sparkling eyes and curly brown hair. She's brave and loves exploring new places. Tara is always ready for an adventure and wears a playful, colorful outfit.",
          "character_image_path": "images/tara.png"
        },
        {
          "character_name": "Leo",
          "character_description": "Leo is Tara's 4-year-old brother. He has a big smile and blond hair that sticks up in all directions. Leo is full of energy and laughter, and he loves following his sister on her adventures. He wears a fun, striped shirt and shorts.",
          "character_image_path": "images/leo.png"
        }
      ]
    },
    {
      "page": 6,
      "story_text": "The parrot said, 'Follow me!' Tara and Leo skipped behind, giggling with glee.",
      "illustration_description": "The parrot flying ahead, leading Tara and Leo through the jungle. Tara and Leo are skipping and laughing together. The path is lined with colorful flowers and tall grasses.",
      "characters": [
        {
          "character_name": "Tara",
          "character_description": "Tara is a curious 5-year-old girl with bright, sparkling eyes and curly brown hair. She's brave and loves exploring new places. Tara is always ready for an adventure and wears a playful, colorful outfit.",
          "character_image_path": "images/tara.png"
        },
        {
          "character_name": "Leo",
          "character_description": "Leo is Tara's 4-year-old brother. He has a big smile and blond hair that sticks up in all directions. Leo is full of energy and laughter, and he loves following his sister on her adventures. He wears a fun, striped shirt and shorts.",
          "character_image_path": "images/leo.png"
        }
      ]
    },
    {
      "page": 7,
      "story_text": "They came to a magical clearing. Tara and Leo twirled around, 'Wow, it's amazing!'",
      "illustration_description": "Tara and Leo in a magical clearing filled with glowing plants and sparkling lights. They are twirling around with joy. The atmosphere is enchanting, with soft, warm colors.",
      "characters": [
        {
          "character_name": "Tara",
          "character_description": "Tara is a curious 5-year-old girl with bright, sparkling eyes and curly brown hair. She's brave and loves exploring new places. Tara is always ready for an adventure and wears a playful, colorful outfit.",
          "character_image_path": "images/tara.png"
        },
        {
          "character_name": "Leo",
          "character_description": "Leo is Tara's 4-year-old brother. He has a big smile and blond hair that sticks up in all directions. Leo is full of energy and laughter, and he loves following his sister on her adventures. He wears a fun, striped shirt and shorts.",
          "character_image_path": "images/leo.png"
        }
      ]
    },
    {
      "page": 8,
      "story_text": "The parrot chirped, 'Time to go home!' Tara and Leo followed, not wanting the fun to end.",
      "illustration_description": "The parrot leading Tara and Leo back through the jungle. Tara waves goodbye to the magical clearing, and Leo looks a little sad but still smiling. The jungle path is inviting and warm.",
      "characters": [
        {
          "character_name": "Tara",
          "character_description": "Tara is a curious 5-year-old girl with bright, sparkling eyes and curly brown hair. She's brave and loves exploring new places. Tara is always ready for an adventure and wears a playful, colorful outfit.",
          "character_image_path": "images/tara.png"
        },
        {
          "character_name": "Leo",
          "character_description": "Leo is Tara's 4-year-old brother. He has a big smile and blond hair that sticks up in all directions. Leo is full of energy and laughter, and he loves following his sister on her adventures. He wears a fun, striped shirt and shorts.",
          "character_image_path": "images/leo.png"
        }
      ]
    },
    {
      "page": 9,
      "story_text": "At last, Tara and Leo saw the jungle's edge. 'We did it!' they cheered.",
      "illustration_description": "Tara and Leo reaching the edge of the jungle. They are cheering and clapping their hands. The jungle behind them looks mysterious and inviting, and the sun is setting with a warm glow.",
      "characters": [
        {
          "character_name": "Tara",
          "character_description": "Tara is a curious 5-year-old girl with bright, sparkling eyes and curly brown hair. She's brave and loves exploring new places. Tara is always ready for an adventure and wears a playful, colorful outfit.",
          "character_image_path": "images/tara.png"
        },
        {
          "character_name": "Leo",
          "character_description": "Leo is Tara's 4-year-old brother. He has a big smile and blond hair that sticks up in all directions. Leo is full of energy and laughter, and he loves following his sister on her adventures. He wears a fun, striped shirt and shorts.",
          "character_image_path": "images/leo.png"
        }
      ]
    },
    {
      "page": 10,
      "story_text": "Home at last, Tara and Leo snuggled up. 'What a day!' said Tara. 'Let's dream of more adventures!' giggled Leo.",
      "illustration_description": "Tara and Leo snuggling under a cozy blanket at home. They are yawning and smiling, with their eyes half-closed. Their room is filled with toys and books, hinting at more adventures to come.",
      "characters": [
        {
          "character_name": "Tara",
          "character_description": "Tara is a curious 5-year-old girl with bright, sparkling eyes and curly brown hair. She's brave and loves exploring new places. Tara is always ready for an adventure and wears a playful, colorful outfit.",
          "character_image_path": "images/tara.png"
        },
        {
          "character_name": "Leo",
          "character_description": "Leo is Tara's 4-year-old brother. He has a big smile and blond hair that sticks up in all directions. Leo is full of energy and laughter, and he loves following his sister on her adventures. He wears a fun, striped shirt and shorts.",
          "character_image_path": "images/leo.png"
        }
      ]
    }
  ]
}

# %%
import os
import base64
from pathlib import Path
from typing import Dict, List, Any, Optional
from dataclasses import dataclass
import concurrent.futures
from concurrent.futures import ThreadPoolExecutor

from openai import OpenAI
from tenacity import retry, stop_after_attempt, wait_exponential, retry_if_exception_type
from PIL import Image
import io


@dataclass
class IllustrationConfig:
    """Configuration for illustration generation."""
    model: str = "gpt-image-1"
    character_size: str = "1024x1024"
    page_size: str = "1024x1024"
    quality: str = "low"
    output_dir: str = "story_illustrations_openai"


class StoryBookIllustrator:
    """A class to generate and manage illustrations for a storybook."""
    
    def __init__(self, story_data: Dict[str, Any], config: Optional[IllustrationConfig] = None):
        """
        Initialize the story book illustrator.
        
        Args:
            story_data: Dictionary containing story book data including characters and pages
            config: Configuration for the illustration generation
        """
        self.story_data = story_data
        self.config = config or IllustrationConfig()
        
        # Setup directories
        self.setup_directories()
        
        # Initialize OpenAI client
        try:
            self.client = OpenAI()
        except Exception as e:
            print(f"Failed to initialize OpenAI client: {e}")
            raise
    
    def setup_directories(self) -> None:
        """Create necessary directories for saving illustrations."""
        # Create main output directory
        self.output_base = Path(self.config.output_dir)
        self.output_base.mkdir(exist_ok=True, parents=True)
        
        # Create characters directory
        self.characters_dir = self.output_base / "characters"
        self.characters_dir.mkdir(exist_ok=True)
        
        # Create pages directory
        self.pages_dir = self.output_base / "pages"
        self.pages_dir.mkdir(exist_ok=True)
    
    @retry(
        stop=stop_after_attempt(3),
        wait=wait_exponential(multiplier=1, min=2, max=10),
        retry=retry_if_exception_type((ConnectionError, TimeoutError))
    )
    def generate_image(self, prompt: str, size: str, characters: List[Path] = None) -> Dict:
        """
        Generate an image using OpenAI's API.
        
        Args:
            prompt: Description for the image generation
            size: Size of the image to generate
            characters: Optional list of character image paths to include
        
        Returns:
            API response containing the generated image
        """
        try:
            if characters:
                # Open all character images
                image_files = [open(str(char_path), "rb") for char_path in characters]
                result = self.client.images.edit(
                    model=self.config.model,
                    prompt=prompt,
                    size=size,
                    image=image_files,
                    quality=self.config.quality,
                )
                # Close all opened files
                for file in image_files:
                    file.close()
            else:
                result = self.client.images.generate(
                    model=self.config.model,
                    prompt=prompt,
                    size=size,
                    quality=self.config.quality,
                )
            return result
        except Exception as e:
            print(f"Image generation failed: {e}")
            raise
    
    def save_image(self, result: Dict, output_path: Path) -> None:
        """
        Save an image from API response to a file.
        
        Args:
            result: API response containing the image data
            output_path: Path where the image should be saved
        """
        try:
            # Get base64 data from response
            image_base64 = result.data[0].b64_json
            image_bytes = base64.b64decode(image_base64)
            
            # Process image with PIL before saving
            image = Image.open(io.BytesIO(image_bytes))
            
            # Save the image
            image.save(output_path)
            print(f"Image saved to {output_path}")
        except Exception as e:
            print(f"Failed to save image: {e}")
            raise
    
    def generate_character_illustrations(self) -> Dict[str, Path]:
        """
        Generate illustrations for all characters in the story.
        
        Returns:
            Dictionary mapping character names to their image paths
        """
        print("Generating character illustrations...")
        character_paths = {}
        
        characters = self.story_data.get("story_characters", [])
        for character in characters:
            name = character.get("character_name")
            description = character.get("character_description")
            
            if not name or not description:
                print(f"Skipping character with missing data: {character}")
                continue
                
            print(f"Generating illustration for character: {name}")
            
            # Generate safe filename
            safe_name = "".join(c if c.isalnum() else "_" for c in name)
            filename = f"{safe_name}.png"
            output_path = self.characters_dir / filename
            
            # Skip if image already exists
            if output_path.exists():
                print(f"Using existing illustration for {name}")
                character_paths[name] = output_path
                character["character_image_path"] = str(output_path)
                continue
                
            # Generate and save character illustration
            try:
                result = self.generate_image(
                    prompt=description,
                    size=self.config.character_size
                )
                self.save_image(result, output_path)
                
                # Update character data with image path
                character["character_image_path"] = str(output_path)
                character_paths[name] = output_path
            except Exception as e:
                print(f"Failed to generate illustration for {name}: {e}")
        
        return character_paths
    
    def process_page_illustration(self, page_data: Dict, page_index: int, character_paths: Dict[str, Path]) -> Dict:
        """
        Process a single page illustration.
        
        Args:
            page_data: The page data dictionary
            page_index: Index of the page in the storybook
            character_paths: Dictionary mapping character names to their image paths
            
        Returns:
            Updated page data with illustration path
        """
        page_num = page_data.get("page", page_index+1)
        description = page_data.get("illustration_description")
        
        if not description:
            print(f"Skipping page {page_num} with missing description")
            return page_data
            
        print(f"Generating illustration for page {page_num}")
        
        # Generate filename for the page
        filename = f"page_{page_num:03d}.png"
        output_path = self.pages_dir / filename
        
        # Skip if image already exists
        if output_path.exists():
            print(f"Using existing illustration for page {page_num}")
            page_data["illustration_path"] = str(output_path)
            return page_data
        
        # Get characters mentioned in this page specifically
        mentioned_characters = []
        if "characters" in page_data:
            for character in page_data["characters"]:
                char_name = character.get("character_name")
                if char_name and char_name in character_paths:
                    mentioned_characters.append(character_paths[char_name])
        
        # Generate and save page illustration
        try:
            # If there are mentioned characters, use them in the image edit
            if mentioned_characters:
                result = self.generate_image(
                    prompt=description,
                    size=self.config.page_size,
                    characters=mentioned_characters[:5]  # API might limit number of images
                )
            else:
                # Otherwise generate a new image
                result = self.generate_image(
                    prompt=description,
                    size=self.config.page_size
                )
            
            self.save_image(result, output_path)
            
            # Update page data with image path
            page_data["illustration_path"] = str(output_path)
        except Exception as e:
            print(f"Failed to generate illustration for page {page_num}: {e}")
            
        return page_data
    
    def generate_page_illustrations_parallel(self, character_paths: Dict[str, Path], max_workers: int = 5) -> None:
        """
        Generate illustrations for all pages in the story in parallel.
        
        Args:
            character_paths: Dictionary mapping character names to their image paths
            max_workers: Maximum number of parallel workers
        """
        print(f"Generating page illustrations in parallel with {max_workers} workers...")
        
        story_pages = self.story_data.get("story_book", [])
        total_pages = len(story_pages)
        
        print(f"Total pages to process: {total_pages}")
        
        # Process pages in parallel
        with ThreadPoolExecutor(max_workers=max_workers) as executor:
            # Submit all tasks
            futures = []
            for i, page in enumerate(story_pages):
                future = executor.submit(
                    self.process_page_illustration,
                    page,
                    i,
                    character_paths
                )
                futures.append(future)
            
            # Wait for all futures to complete and update story data
            for i, future in enumerate(concurrent.futures.as_completed(futures)):
                try:
                    updated_page = future.result()
                    # Find the page to update
                    for idx, page in enumerate(self.story_data["story_book"]):
                        if page.get("page") == updated_page.get("page"):
                            self.story_data["story_book"][idx] = updated_page
                            break
                except Exception as e:
                    print(f"Error processing page: {e}")
        
        print("All page illustrations completed")
    
    def generate_all_illustrations(self, parallel: bool = True, max_workers: int = 5) -> Dict[str, Any]:
        """
        Generate all illustrations for the storybook.
        
        Args:
            parallel: Whether to generate page illustrations in parallel
            max_workers: Maximum number of parallel workers
            
        Returns:
            Updated story data with all illustration paths
        """
        try:
            # Generate character illustrations first (this is sequential)
            character_paths = self.generate_character_illustrations()
            
            # Then generate page illustrations using character illustrations
            if parallel:
                self.generate_page_illustrations_parallel(character_paths, max_workers)
            else:
                self.generate_page_illustrations(character_paths)
            
            print("All illustrations generated successfully")
            return self.story_data
            
        except Exception as e:
            print(f"Illustration generation failed: {e}")
            raise
    
    def generate_page_illustrations(self, character_paths: Dict[str, Path]) -> None:
        """
        Generate illustrations for all pages in the story sequentially.
        
        Args:
            character_paths: Dictionary mapping character names to their image paths
        """
        print("Generating page illustrations sequentially...")
        
        story_pages = self.story_data.get("story_book", [])
        total_pages = len(story_pages)
        
        for i, page in enumerate(story_pages):
            updated_page = self.process_page_illustration(page, i, character_paths)
            
            # Update the page in the story data
            for idx, orig_page in enumerate(self.story_data["story_book"]):
                if orig_page.get("page") == updated_page.get("page"):
                    self.story_data["story_book"][idx] = updated_page
                    break


def main():
    """Main function to run the illustration generator."""
    # Import storybook data from a file (optional)
    # import json
    # with open("your_storybook.json", "r") as f:
    #     story_book = json.load(f)
    
    # Custom configuration
    config = IllustrationConfig(
        model="gpt-image-1",
        character_size="1024x1024",
        page_size="1024x1024",
        quality="medium",
        output_dir="openai/story_illustrations_3"
    )
    
    # Initialize and run the illustrator
    illustrator = StoryBookIllustrator(story_book, config)
    
    # Generate all illustrations in parallel (default: 5 workers)
    updated_story = illustrator.generate_all_illustrations(parallel=True, max_workers=3)
    
    print("Story illustration process completed.")
    
    # Save the updated story data
    import json
    with open("illustrated_story.json", "w") as f:
        json.dump(updated_story, f, indent=2)


if __name__ == "__main__":
    main()
# Out:
# Generating character illustrations...
# Generating illustration for character: Tara
# Image saved to openai/story_illustrations_3/characters/Tara.png
# Generating illustration for character: Leo
# Image saved to openai/story_illustrations_3/characters/Leo.png
# Generating page illustrations in parallel with 3 workers...
# Total pages to process: 10
# Generating illustration for page 1
# Generating illustration for page 2
# Generating illustration for page 3
